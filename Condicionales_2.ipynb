# %% [markdown]
# # condicionales

# %%
x = 12

if x < 10:
    print('Pequeño')
if x > 20:
    print('Grande')

print('Final')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 78
if x == 5 : 
    print('Igual a 5')
if x > 4 : 
   print('Más grande que 4')
if  x >= 5 :
    print('Igual o más que 5')
if x < 6 : print('Menor a 6') 
if x <= 5 :
    print('Menor o igual a  5')
if x != 6 :
    print('No es igual a 6')

# %%
num = int(input("¿Cuál es su nota?: "))

if num >= 90:
    print("Grade A")
elif num >= 80:
    print("Grade B")
elif num >= 70:
    print("Grade C")
elif num >= 60:
    print("Grade D")
elif num >= 40:
    print("Grade E")
#else:
    #print("Grade F")

# %% [markdown]
# ####  Decisiones unidireccionales

# %%
x = 6
print('Antes de 5')
print('__________')
if  x == 5 :
    print('Es 5')
    print('Todávía es 5')
    print('5 por tercera vez')
print('Después ')
print('_____________________')
print('Antes de 6')
print(x)
if x == 6 :
    print('Es 6')
    print('Todavía 6')
    print('Tercer 6')
print('Depués de 6')
print(x)

# %% [markdown]
# #### Decisiones anidadas
#
# ![image.png](attachment:image.png)

# %%
x = -2
if x > 1 :
    print('Más que 1')
    if x < 100 : 
        print('Menor a 100') 
print('Final')

# %%
x = 5
if x > 2:
    print('***1. Mayor a 2')
    print('***2. Sigue siendo mayor')
print('***3. **Hecho con 2**')
print("_________________________")
for i in range(5) :
    print('***4. ***********imprimo i y vale:',i, '*****')
    if i > 2 : 
         print('***6. Mayor que 2')
    print('***5. Hecho con i = ', i)
print('Final ')

# %%
#determinar un año bisiesto
year=input("Ingrese un año: ")
year = int(year)
#Un año es bisiesto si es divisible entre 4,
#excepto aquellos divisibles entre 100 pero no entre 400.
if year % 4 == 0:
    if year %100 != 0:
          print("El año", year, "es bisiesto")
    elif year %400 == 0:
          print("El año", year, "es bisiesto")
    else:
          print("El año", year, "no es bisiesto")   
else:
     print ("El año", year, "no es bisiesto")

# %%
y = 2020%4
h = 2020%100
x = 2020%400
y,h,x

# %% [markdown]
# ### Decisiones bidireccionales
#
# ![image.png](attachment:image.png)

# %%
x = 1

if x > 2 :
    print('Mayor')
else :
    print('Menor')

print('Final')

# %% [markdown]
# ### Multidireccional
#
# ![image.png](attachment:image.png)

# %%
x = 15
if x < 2 :
    print('menor')
elif x < 10 :
    print('medio')
else :
    print('más grande')
print('Final')

# %%
x = 5
if x < 2 :
    print('menor')
elif x < 10 :
    print('medio')
else :
    print('más grande')
print('Final')
# Out:
# medio
# Final

# %%
x = 20
if x < 2 :
    print('menor')
elif x < 10 :
    print('medio')
else :
    print('más grande')
print('Final')
# Out:
# más grande
# Final

# %%
#x = 101
x = 1
#x = 9
#x = 12
#x = 22
#x = 90
#x = 101
if x < 2 :
    print('Menor')
elif x < 10 :
    print('Medio')
elif x < 20 : 
    print('Grande')
elif x < 40 : 
    print('Muy grande')
elif x < 100:
    print('Muy muy grande')
else :
    print('Enorme')

# %%
# sin else
x = 89
if x < 2 :
    print('pequeño')
elif x < 10 :
    print('medio')

print('Final')
# Out:
# Final

# %% [markdown]
# # Tratar errores

# %%
a, b = 20, 0

resultado = a/b

print(resultado)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-109-5d02056d3cb5> in <module>
#       1 a, b = 20, 0
#       2
# ----> 3 resultado = a/b
#       4
#       5 print(resultado)
#
# ZeroDivisionError: division by zero

# %%
a, b = 23, 0
try:
    resultado = a/b
except:
    print("Hay un error en los valores de entrada")
# Out:
# Hay un error en los valores de entrada

# %%
while True:
    try:
        x = int(input("Dame un numero: "))
        break  # Si no da error, corto el while con break
    except ValueError:
        print("Eso no es un número, prueba otra vez...")
# Out:
# Dame un numero: m
# Eso no es un número, prueba otra vez...

# %% [markdown]
# Si quisiéramos distinguir el tipo de error ocurrido, para tomar distintas acciones o mensajes, debemos especificarlo en except, por ejemplo:

# %%
a, b, c = 23, 0, "A"
try:
    resultado = a/c
except ZeroDivisionError:
    print("Error, division por cero.")
except TypeError:
    print("Error en el tipo de dato.")
# Out:
# Error en el tipo de dato.

# %%
a, b, c = 23, 0, "A"

try:
    resultado = a/b
except ZeroDivisionError:
    print("Error, division por cero.")
except TypeError:
    print("Error en el tipo de dato.")

# Resultado:
# Error, division por cero.

try:
    resultado = a/c
except ZeroDivisionError:
    print("Error, division por cero.")
except TypeError:
    print("Error en el tipo de dato.")

# Resultado:
# Error en el tipo de dato.
# Out:
# Error, division por cero.
# Error en el tipo de dato.
